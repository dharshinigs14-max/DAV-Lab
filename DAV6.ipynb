# %%
import pandas as pd

data = {
    "Glucose": [148, 85, 183, 89, 137],
    "BloodPressure": [72, 66, 64, 66, 40],
    "SkinThickness": [35, 29, 0, 23, 35],
    "Insulin": [0, 0, 0, 94, 168],
    "BMI": [33.6, 26.6, 23.3, 28.1, 43.1],
    "DiabetesPedigreeFunction": [0.627, 0.351, 0.672, 0.167, 2.288],
    "Age": [50, 31, 32, 21, 33],
    "Outcome": [1, 0, 1, 0, 1]
}

df = pd.DataFrame(data)

df.to_csv("uci_diabetes.csv", index=False)
df.to_csv("pima_diabetes.csv", index=False)

print("Datasets created successfully.")
# Out:
# Datasets created successfully.

# %%
uci_diabetes = pd.read_csv("uci_diabetes.csv")
pima_diabetes = pd.read_csv("pima_diabetes.csv")

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Read datasets
uci_diabetes = pd.read_csv("uci_diabetes.csv")
pima_diabetes = pd.read_csv("pima_diabetes.csv")

# Display sample data
print("UCI Diabetes Dataset Sample:")
print(uci_diabetes.head())

print("\nPima Indians Diabetes Dataset Sample:")
print(pima_diabetes.head())

# Numerical columns
numerical_columns = [
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age"
]

# Function for univariate analysis
def univariate_analysis(df, columns):
    stats = {}

    for col in columns:
        stats[col] = {
            "Mean": np.mean(df[col]),
            "Median": np.median(df[col]),
            "Mode": df[col].mode()[0],
            "Variance": np.var(df[col], ddof=1),
            "Standard Deviation": np.std(df[col], ddof=1),
            "Skewness": skew(df[col]),
            "Kurtosis": kurtosis(df[col])
        }

    return pd.DataFrame(stats).T

# Perform analysis
uci_stats = univariate_analysis(uci_diabetes, numerical_columns)
pima_stats = univariate_analysis(pima_diabetes, numerical_columns)

# Display results
print("\nUCI Diabetes Dataset Statistics:")
print(uci_stats)

print("\nPima Indians Diabetes Dataset Statistics:")
print(pima_stats)
# Out:
# UCI Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# Pima Indians Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      148             72             35        0  33.6
# 1       85             66             29        0  26.6
# 2      183             64              0        0  23.3
# 3       89             66             23       94  28.1
# 4      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
# UCI Diabetes Dataset Statistics:
#                              Mean   Median    Mode     Variance  \
# Glucose                   128.400  137.000  85.000  1718.800000
# BloodPressure              61.600   66.000  66.000   154.800000
# SkinThickness              24.400   29.000  35.000   210.800000
# Insulin                    52.400    0.000   0.000  5832.800000
# BMI                        30.940   28.100  23.300    60.053000
# DiabetesPedigreeFunction    0.821    0.627   0.167     0.715135
# Age                        33.400   32.000  21.000   109.300000
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            41.458413  0.109936 -1.413529
# BloodPressure                      12.441865 -1.272538  0.001492
# SkinThickness                      14.518953 -1.100479 -0.326568
# Insulin                            76.372770  0.743630 -1.124426
# BMI                                 7.749387  0.760535 -0.769468
# DiabetesPedigreeFunction            0.845657  1.276987 -0.027183
# Age                                10.454664  0.648457 -0.394305
#
# Pima Indians Diabetes Dataset Statistics:
#                              Mean   Median    Mode     Variance  \
# Glucose                   128.400  137.000  85.000  1718.800000
# BloodPressure              61.600   66.000  66.000   154.800000
# SkinThickness              24.400   29.000  35.000   210.800000
# Insulin                    52.400    0.000   0.000  5832.800000
# BMI                        30.940   28.100  23.300    60.053000
# DiabetesPedigreeFunction    0.821    0.627   0.167     0.715135
# Age                        33.400   32.000  21.000   109.300000
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            41.458413  0.109936 -1.413529
# BloodPressure                      12.441865 -1.272538  0.001492
# SkinThickness                      14.518953 -1.100479 -0.326568
# Insulin                            76.372770  0.743630 -1.124426
# BMI                                 7.749387  0.760535 -0.769468
# DiabetesPedigreeFunction            0.845657  1.276987 -0.027183
# Age                                10.454664  0.648457 -0.394305
