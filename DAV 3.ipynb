# %%
# %%writefile data.csv
# column1,column2,existing_column,another_column,category_column,numeric_column
# A,Math,60,80,Group1,90
# B,Science,45,95,Group2,75
# C,English,70,60,Group1,88
# D,Math,55,85,Group2,92
# E,Science,90,70,Group1,95
# F,English,40,50,Group2,68
# G,Math,75,65,Group1,84
# H,Science,82,90,Group2,78
# I,English,58,55,Group1,86
# J,Math,65,45,Group2,91
# Out:
# Overwriting data.csv

# %%
import pandas as pd

df = pd.read_csv("data.csv")

df.head()
# Out:
#   column1  column2  existing_column  another_column category_column  \
# 0       A     Math               60              80          Group1
# 1       B  Science               45              95          Group2
# 2       C  English               70              60          Group1
# 3       D     Math               55              85          Group2
# 4       E  Science               90              70          Group1
#
#    numeric_column
# 0              90
# 1              75
# 2              88
# 3              92
# 4              95

# %%
import pandas as pd
# Load dataset into a DataFrame
df = pd.read_csv('data.csv')
# Display first and last few rows
print("First 5 rows:\n", df.head())
print("Last 5 rows:\n", df.tail())
# Check data types and general info
df.info()
# Summary statistics
print("Summary statistics:\n", df.describe())
# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)
# Create a new column
df['new_column'] = df['existing_column'] * 2
# Create a Series and perform operations
series = df['existing_column']
print("Series addition:", series + 10)
# Filter rows based on conditions
filtered_df = df[(df['existing_column'] > 50) & (df['another_column'] < 100)]
print("Filtered DataFrame:\n", filtered_df)
# Grouping and aggregation
grouped = df.groupby('category_column')['numeric_column'].mean()
print("Grouped mean:\n", grouped)
# Sorting
df_sorted = df.sort_values(by='numeric_column', ascending=False)
print("Sorted DataFrame:\n", df_sorted)
# Boolean masking
masked_df = df[df['numeric_column'] > df['numeric_column'].median()]

print("Masked DataFrame:\n", masked_df)
# Remove duplicates and drop missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Create a new DataFrame with selected columns
subset_df = df[['column1', 'column2']]
# Save the new DataFrame to a CSV file
subset_df.to_csv('filtered_data.csv', index=False)
# Compute summary statistics
print("Total sum:", df['numeric_column'].sum())
print("Mean:", df['numeric_column'].mean())
print("Standard Deviation:", df['numeric_column'].std())
# Out:
# First 5 rows:
#    column1  column2  existing_column  another_column category_column  \
# 0       A     Math               60              80          Group1
# 1       B  Science               45              95          Group2
# 2       C  English               70              60          Group1
# 3       D     Math               55              85          Group2
# 4       E  Science               90              70          Group1
#
#    numeric_column
# 0              90
# 1              75
# 2              88
# 3              92
# 4              95
# Last 5 rows:
#    column1  column2  existing_column  another_column category_column  \
# 5       F  English               40              50          Group2
# 6       G     Math               75              65          Group1
# 7       H  Science               82              90          Group2
# 8       I  English               58              55          Group1
# 9       J     Math               65              45          Group2
#
#    numeric_column
# 5              68
# 6              84
# 7              78
# 8              86
# 9              91
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   column1          10 non-null     str
#  1   column2          10 non-null     str
#  2   existing_column  10 non-null     int64
#  3   another_column   10 non-null     int64
#  4   category_column  10 non-null     str
#  5   numeric_column   10 non-null     int64
# dtypes: int64(3), str(3)
# memory usage: 612.0 bytes
# Summary statistics:
#         existing_column  another_column  numeric_column
# count        10.000000       10.000000       10.000000
# mean         64.000000       69.500000       84.700000
# std          15.733898       17.392527        8.551153
# min          40.000000       45.000000       68.000000
# 25%          55.750000       56.250000       79.500000
# 50%          62.500000       67.500000       87.000000
# 75%          73.750000       83.750000       90.750000
# max          90.000000       95.000000       95.000000
# Series addition: 0     70
# 1     55
# 2     80
# 3     65
# 4    100
# 5     50
# 6     85
# 7     92
# 8     68
# 9     75
# Name: existing_column, dtype: int64
# Filtered DataFrame:
#    column1  column2  existing_column  another_column category_column  \
# 0       A     Math               60              80          Group1
# 2       C  English               70              60          Group1
# 3       D     Math               55              85          Group2
# 4       E  Science               90              70          Group1
# 6       G     Math               75              65          Group1
# 7       H  Science               82              90          Group2
# 8       I  English               58              55          Group1
# 9       J     Math               65              45          Group2
#
#    numeric_column  new_column
# 0              90         120
# 2              88         140
# 3              92         110
# 4              95         180
# 6              84         150
# 7              78         164
# 8              86         116
# 9              91         130
# Grouped mean:
#  category_column
# Group1    88.6
# Group2    80.8
# Name: numeric_column, dtype: float64
# Sorted DataFrame:
#    column1  column2  existing_column  another_column category_column  \
# 4       E  Science               90              70          Group1
# 3       D     Math               55              85          Group2
# 9       J     Math               65              45          Group2
# 0       A     Math               60              80          Group1
# 2       C  English               70              60          Group1
# 8       I  English               58              55          Group1
# 6       G     Math               75              65          Group1
# 7       H  Science               82              90          Group2
# 1       B  Science               45              95          Group2
# 5       F  English               40              50          Group2
#
#    numeric_column  new_column
# 4              95         180
# 3              92         110
# 9              91         130
# 0              90         120
# 2              88         140
# 8              86         116
# 6              84         150
# 7              78         164
# 1              75          90
# 5              68          80
# Masked DataFrame:
#    column1  column2  existing_column  another_column category_column  \
# 0       A     Math               60              80          Group1
# 2       C  English               70              60          Group1
# 3       D     Math               55              85          Group2
# 4       E  Science               90              70          Group1
# 9       J     Math               65              45          Group2
#
#    numeric_column  new_column
# 0              90         120
# 2              88         140
# 3              92         110
# 4              95         180
# 9              91         130
# Total sum: 847
# Mean: 84.7
# Standard Deviation: 8.55115326854935
